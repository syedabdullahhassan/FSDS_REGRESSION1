# %%
import pandas as pd

# %%
## Data Ingestions step
df=pd.read_csv("C:/Users/Administrator/Krish_Naik/FSDS_Regression1/notebooks/data/finalTrain25th.csv")

# %%
df.head(5)
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
df['Delivery_person_ID'].value_counts()
# Out:
# JAPRES11DEL02     67
# PUNERES01DEL01    67
# VADRES11DEL02     66
# VADRES08DEL02     66
# JAPRES03DEL01     66
#                   ..
# GOARES01DEL03      7
# DEHRES18DEL03      7
# KOCRES16DEL03      6
# KOLRES09DEL03      6
# BHPRES010DEL03     5
# Name: Delivery_person_ID, Length: 1320, dtype: int64

# %%
df['Delivery_person_ID'].unique()
# Out:
# array(['DEHRES17DEL01', 'KOCRES16DEL01', 'PUNERES13DEL03', ...,
#        'KOCRES04DEL01', 'BHPRES06DEL03', 'GOARES03DEL03'], dtype=object)

# %%
df["Delivery_person_Age"].fillna(value=df["Delivery_person_Age"].mean(),inplace=True)
df["Delivery_person_Ratings"].fillna(value=df["Delivery_person_Ratings"].mean(),inplace=True)

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
# ...

# %%
df.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count         43730.000000             43676.000000         45584.000000
# mean             29.566911                 4.633774            17.017948
# std               5.815064                 0.334744             8.185674
# min              15.000000                 1.000000           -30.905562
# 25%              25.000000                 4.500000            12.933284
# 50%              30.000000                 4.700000            18.551440
# 75%              35.000000                 4.900000            22.728163
# max              50.000000                 6.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          45584.000000                45584.000000
# mean              70.229684                   17.465480
# std               22.885575                    7.335562
# min              -88.366217                    0.010000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
# ...

# %%
def impute_nan(df,variable):
    most_frequent_category=df[variable].value_counts().index[0]
    df[variable].fillna(most_frequent_category,inplace=True)

# %%
for feature in["Weather_conditions","Road_traffic_density","Festival","City"]:
    impute_nan(df,feature)

# %%
df.isnull().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weather_conditions             0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken (min)               0
# dtype: int64

# %%
df["Time_Orderd"].value_counts()
# Out:
# 29.566910587697233    1731
# 21:55                  461
# 17:55                  456
# 0.833333333            449
# 22:20                  448
#                       ...
# 14:30                   57
# 14:15                   56
# 0.666666667             53
# 13:20                   52
# 16:30                   51
# Name: Time_Orderd, Length: 177, dtype: int64

# %%
## Lets drop the id column
df=df.drop(labels=["ID"],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9212\926753798.py in <module>
#       1 ## Lets drop the id column
# ----> 2 df=df.drop(labels=["ID"],axis=1)
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      DEHRES17DEL01                 36.0                      4.2
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
## check for duplicated records
df.duplicated().sum()
# Out:
# 0

# %%
## segregate numerical and categorical columns

numerical_columns=df.columns[df.dtypes!='object']
categorical_columns=df.columns[df.dtypes=='object']
print("Numerical columns:",numerical_columns)
print('Categorical Columns:',categorical_columns)
# Out:
# Numerical columns: Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Vehicle_condition',
#        'multiple_deliveries', 'Time_taken (min)'],
#       dtype='object')
# Categorical Columns: Index(['Delivery_person_ID', 'Order_Date', 'Time_Orderd', 'Time_Order_picked',
#        'Weather_conditions', 'Road_traffic_density', 'Type_of_order',
#        'Type_of_vehicle', 'Festival', 'City'],
#       dtype='object')

# %%
df[categorical_columns].describe()
# Out:
#        Delivery_person_ID  Order_Date   Time_Orderd Time_Order_picked  \
# count               45584       45584  45584.000000             45584
# unique               1320          44    177.000000               193
# top         JAPRES11DEL02  15-03-2022     29.566911             21:30
# freq                   67        1192   1731.000000               495
#
#        Weather_conditions Road_traffic_density Type_of_order Type_of_vehicle  \
# count               45584                45584         45584           45584
# unique                  6                    4             4               4
# top                   Fog                  Low         Snack      motorcycle
# freq                 8269                16077         11530           26429
#
#        Festival           City
# count     45584          45584
# unique        2              3
# top          No  Metropolitian
# freq      44688          35287

# %%
df['Weather_conditions'].value_counts()
#freq==fog=8269
# Out:
# Fog           8269
# Stormy        7584
# Cloudy        7533
# Sandstorms    7494
# Windy         7422
# Sunny         7282
# Name: Weather_conditions, dtype: int64

# %%
df['Type_of_order'].value_counts()
#freq==Snack=11530
# Out:
# Snack     11530
# Meal      11456
# Drinks    11321
# Buffet    11277
# Name: Type_of_order, dtype: int64

# %%
df['Road_traffic_density'].value_counts()
# Out:
# Low       16077
# Jam       14139
# Medium    10945
# High       4423
# Name: Road_traffic_density, dtype: int64

# %%
df['Festival'].value_counts()
# Out:
# No     44688
# Yes      896
# Name: Festival, dtype: int64

# %%
df['City'].value_counts()
# Out:
# Metropolitian    35287
# Urban            10133
# Semi-Urban         164
# Name: City, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
x=0
for i in numerical_columns:
    sns.histplot(data=df,x=i,kde=True)
    print('\n')
    plt.show()

# %%
plt.figure(figsize=(8,6))
x=0
for i in categorical_columns:
    sns.histplot(data=df,x=i,kde=True)
    print('\n')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9212\2378081404.py in <module>
#       2 x=0
#       3 for i in categorical_columns:
# ----> 4     sns.histplot(data=df,x=i,kde=True)
#       5     print('\n')
#       6     plt.show()
#
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1443
#    1444     # Attach the axes to the plotter, setting up unit conversions
# -> 1445     p._attach(ax, log_scale=log_scale)
#    1446
#    1447     # Default to discrete bins for categorical variables
#
# ...

# %%
## correlation
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
numerical_columns=df.columns[df.dtypes!='object']
categorical_columns=df.columns[df.dtypes=='object']
print("Numerical columns:",numerical_columns)
print('Categorical Columns:',categorical_columns)
# Out:
# Numerical columns: Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Vehicle_condition',
#        'multiple_deliveries', 'Time_taken (min)'],
#       dtype='object')
# Categorical Columns: Index(['Delivery_person_ID', 'Order_Date', 'Time_Orderd', 'Time_Order_picked',
#        'Weather_conditions', 'Road_traffic_density', 'Type_of_order',
#        'Type_of_vehicle', 'Festival', 'City'],
#       dtype='object')

# %%
#Multicolinerity
#Corelation between Restaurant_longitude & Delivery_location_longitude=0.92-High
#Corelation between Restaurant_latitude & Delivery_location_latitude=0.87-High
#we can drop any two of them

##Currently we will not execute this
## df.drop(labels=['Restaurant_longitude','Restaurant_latitude '],axis=1)

# %%
sns.pairplot(df)

# %%
# most of feature are positively corelated with each other

# %%
df['Weather_conditions'].unique()
# Out:
# array(['Fog', 'Stormy', 'Sandstorms', 'Windy', 'Cloudy', 'Sunny'],
#       dtype=object)

# %%
df['Road_traffic_density'].unique()
# Out:
# array(['Jam', 'High', 'Medium', 'Low'], dtype=object)

# %%
df['Type_of_order'].unique()
# Out:
# array(['Snack', 'Meal', 'Drinks', 'Buffet'], dtype=object)

# %%
order_map={'Snack':1, 'Meal':2, 'Drinks':3, 'Buffet':4}
order_map
# Out:
# {'Snack': 1, 'Meal': 2, 'Drinks': 3, 'Buffet': 4}

# %%
df['City'].unique()
# Out:
# array(['Metropolitian', 'Urban', 'Semi-Urban'], dtype=object)

# %%
city_map={'Metropolitian':1, 'Urban':2, 'Semi-Urban':3}
city_map
# Out:
# {'Metropolitian': 1, 'Urban': 2, 'Semi-Urban': 3}

# %%
df['Weather_conditions'].unique()
# Out:
# array(['Fog', 'Stormy', 'Sandstorms', 'Windy', 'Cloudy', 'Sunny', nan],
#       dtype=object)

# %%
Weather_map={}

# %%
df['Festival'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Time_Order_picked'].unique()
# Out:
# array(['22:10', '15:05', '17:40', '9:30', '20:05', '20:35', '15:10',
#        '20:40', '20:50', '21:30', '20:25', '22:45', '8:30', '19:45',
#        '12:30', '18:50', '23:30', '21:35', '23:45', '22:50', '22:40',
#        '23:35', '13:40', '21:45', '19:10', '14:25', '11:10', '9:55',
#        '8:55', '23:10', '17:30', '18:35', '19:50', '19:25', '0.458333333',
#        '19:15', '16:55', '11:40', '15:15', '22:55', '22:25', '20:55',
#        '23:05', '0.75', '0.958333333', '9:40', '20:20', '22:35',
#        '0.916666667', '23:55', '15:40', '10:30', '0.875', '10:50',
#        '16:05', '20:15', '12:15', '15:45', '22:15', '10:45', '15:30',
#        '24:05:00', '21:25', '12:45', '21:15', '18:20', '18:25', '11:50',
#        '12:50', '10:55', '21:40', '10:20', '17:55', '23:50', '12:55',
#        '24:10:00', '10:40', '0.375', '20:45', '0.833333333', '23:15',
#        '22:20', '21:05', '0.708333333', '24:15:00', '21:20', '14:35',
# ...

# %%
df['Time_Orderd'].unique()
# Out:
# array(['21:55', '14:55', '17:30', '9:20', '19:50', '20:25', '20:30',
#        '20:40', '21:15', '20:20', '22:30', '8:15', '19:30', '12:25',
#        '18:35', '20:35', '23:20', '21:20', '23:35', '22:35', '23:25',
#        '13:35', '21:35', '18:55', '14:15', '0.458333333', '9:45', '8:40',
#        '0.958333333', '17:25', nan, '19:45', '19:10', '10:55', '21:40',
#        '0.791666667', '16:45', '11:30', '15:10', '22:45', '22:10',
#        '20:45', '22:50', '17:55', '9:25', '20:15', '22:25', '22:40',
#        '23:50', '15:25', '10:20', '20:55', '10:40', '15:55', '20:10',
#        '12:10', '15:30', '10:35', '21:10', '20:50', '12:35', '0.875',
#        '23:40', '18:15', '18:20', '11:45', '12:45', '23:30', '10:50',
#        '21:25', '10:10', '17:50', '22:20', '12:40', '23:55', '10:25',
#        '8:45', '23:45', '19:55', '22:15', '23:10', '9:15', '18:25',
#        '18:45', '16:50', '1', '14:20', '10:15', '8:50', '0.375', '17:45',
# ...
